# %%
# How does the transmission from a uniform not point source to an iris located at a distance L 
# change as a function of iris radius ?

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
numPoints = 1000000 # Number of points in MC
R = 1.5/2 # Diameter of a non-point source
L = 108.8 # Distance from source to Iris

# %%
# Transmission as a function iris radius

trans = []
for k in range(1, 40):
    rIris = 10*k/40
    
    # Generating distribution on non-point source
    r = [R*np.sqrt( np.random.uniform() ) for _ in range(numPoints)]
    theta =  [ np.random.uniform(0, 2*np.pi)  for _ in range(numPoints)]
    X = [ r[i]*np.cos(theta[i]) for i in range(numPoints) ]
    Y = [ r[i]*np.sin(theta[i]) for i in range(numPoints) ]
    # plt.scatter(X, Y)

    # Generating phi and theta of emission from the source
    theta = [ np.random.uniform(0, 2*np.pi) for _ in range(numPoints)]
    phi = [ np.arccos(2*np.random.uniform() - 1) for _ in range(numPoints)]
    #X = [np.sin(phi[i])*np.cos(theta[i]) for i in range(numPoints) ]
    #Y = [np.sin(phi[i])*np.sin(theta[i]) for i in range(numPoints) ]
    #Z = [np.cos(phi[i]) for i in range(numPoints) ]
    #fig = plt.figure(figsize = (10, 7))
    #ax = plt.axes(projection ="3d")
    # top: elev=90, side: elev=0
    #ax.view_init(elev=0, azim=0)
    #ax.scatter(X, Y, Z, color = "green")

    # Calculating transveral position is within iris at position L
    rSource_Iris = [L/np.abs(np.cos(phi[i])) for i in range(numPoints) ]
    rAtIris = []
    for i in range(numPoints):
        XX = X[i] + rSource_Iris[i]*np.sin(phi[i])*np.cos(theta[i]) 
        YY = Y[i] + rSource_Iris[i]*np.sin(phi[i])*np.sin(theta[i]) 
        rTemp = np.sqrt( XX*XX + YY*YY )
        if rTemp < rIris and (phi[i] < 0.025 or phi[i] > np.pi - 0.025):
            rAtIris.append(rTemp)
            
    trans.append(len(rAtIris))

# %%
plt.figure(figsize=(8, 8))

X = [10*k/40 for k in range(1,40)]
plt.plot(X, trans)
plt.xlabel('Iris radius [mm]')
plt.ylabel('Transmission [AU]')
plt.show()
